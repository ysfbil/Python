# %% [markdown]
# # Google Colab Çalışma Ortamı
#
# Colaboratory veya kısaca 'Colab', tarayıcınızı kullanarak Python programlama dilince uygulamalarını yapmaya olanak tanır.
#
# * Kuruluma ihtiyaç yoktur.
# * GPU ve TPU'lara ücretsiz erişim sağlar.
# * Ortak çalışma imkanı sunar.

# %% [markdown]
# ### Merhaba!

# %%
print('Merhaba Dünya!')
# Out:
# Merhaba Dünya!

# %%
bir_günde_saniye_sayısı = 24 * 60 * 60
bir_günde_saniye_sayısı
# Out:
# 86400

# %%
print(type(bir_günde_saniye_sayısı))
# Out:
# <class 'int'>

# %%
print(bir_günde_saniye_sayısı *2)
# Out:
# 172800

# %% [markdown]
# ## CPU Hakkında

# %%
# !cat /proc/cpuinfo
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## RAM Hakkında

# %%
# !cat /proc/meminfo
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# # Veri Bilimi
#
# Veri bilimi için `Python`'ın farklı kütüphanelerini Colab ortamında kullanarak analiz ve görselleştirme işlemleri de yapabiliriz.
#
# Görselleştirme için `Numpy` ve `Matplotlib` kütüphanelerini kullanalım!

# %%
import numpy as np
from matplotlib import pyplot as  plt

ys = 50 + np.random.randn(50)
x = [x for x in range (len(ys))]

plt.plot(x, ys, '*')
plt.fill_between(x, ys, 45, where = (ys >45), facecolor = 'm', alpha = 0.5)

plt.title("Örnek Gösterim")
plt.show()

# %%
ys
# Out:
# array([51.36409762, 50.35981725, 50.34519041, 50.56587628, 49.25414704,
#        50.93789477, 51.62107057, 51.31182988, 49.80338227, 49.10103111,
#        49.24408355, 48.41052811, 48.88774122, 49.15073069, 50.14797126,
#        51.15255471, 48.80636693, 52.26201141, 49.10869826, 50.06326535,
#        49.28453668, 49.11317815, 51.17633213, 49.41273202, 50.5728252 ,
#        50.4677097 , 49.30341306, 52.26122729, 48.36744164, 49.46348766,
#        48.71455209, 48.887393  , 50.92346692, 49.2735549 , 51.05343378,
#        51.49832131, 48.78349412, 49.19952276, 50.19274928, 49.26642618,
#        49.4627263 , 50.41923761, 50.49297211, 50.16175979, 51.08160858,
#        50.17949173, 51.15986019, 50.73195646, 50.26464293, 47.89478122])

# %% [markdown]
# ### Veri görselleştirme ve Google Colab Tutorial Kullanma

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_point().encode(
  x='Horsepower',
  y='Miles_per_Gallon',
  color='Origin'
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Google Colab Kimlik Doğrulama Adımı

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive
# /gdrive

# %% [markdown]
# Drive'da dosyaları inceleme

# %%
# !ls "/gdrive/My Drive/Calisma_ortami/"
# Out:
# Colab_CalismaOrtami.ipynb  rakam_tanima_CNN_MNIST.py

# %%
import os 
os.chdir("/gdrive/My Drive/Calisma_ortami/")

# %%
# !ls
# Out:
# Colab_CalismaOrtami.ipynb  rakam_tanima_CNN_MNIST.py

# %% [markdown]
# ### Kütüphane Kurulumları

# %%
# !pip install -q keras
import keras
# Out:
# Using TensorFlow backend.

# %%
# !apt-get install graphviz -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 33 not upgraded.

# %% [markdown]
# ## GPU Özelliklerinin Görüntülenmesi

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import tensorflow_hub as hub

# %%
print("TF vesion:", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is", "available" if tf.test.is_gpu_available() else "NOT AVAILABLE")
# Out:
# TF vesion: 2.2.0
# Hub version: 0.8.0
# WARNING:tensorflow:From <ipython-input-3-b46a397043d4>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU is available

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 18340941968858320142, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 2327397103211002139
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 1972138688913097246
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1091343636140441494
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
# !python3 rakam_tanima_CNN_MNIST.py
# Out:
# Using TensorFlow backend.
# 2020-07-06 22:10:34.164098: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...
# 11493376/11490434 [==============================] - 1s 0us/step
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
# 2020-07-06 22:10:37.066140: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-06 22:10:37.083180: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-06 22:10:37.083749: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...

# %%
# !ls
# Out:
# Colab_CalismaOrtami.ipynb  rakam_tanima_CNN_MNIST.py

# %% [markdown]
# Sanal makineyi yeniden başlatma işlemi

# %%
# !kill -9 -1
