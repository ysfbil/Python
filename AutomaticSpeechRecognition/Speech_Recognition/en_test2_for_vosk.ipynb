# %%
# !pip install vosk

# %%
from vosk import Model, KaldiRecognizer, SetLogLevel
import sys
import os
import wave
import json
import ast

# %%
wf = wave.open("/content/drive/MyDrive/Colab Notebooks/english_tale.wav", "rb")

if wf.getnchannels() != 1 or wf.getsampwidth() != 2 or wf.getcomptype() != "NONE":
    print ("Audio file must be WAV format mono PCM.")
    exit (1)

# %%
model = Model(lang="en-us")

# You can also init model by name or with a folder path
# model = Model(model_name="vosk-model-en-us-0.21")
# model = Model("models/en")

# %%
rec = KaldiRecognizer(model, wf.getframerate())
rec.SetWords(True)
rec.SetPartialWords(True)

# %%
sonuc_str=""
i=1

while True:
    data = wf.readframes(4000)
    if len(data) == 0:
        break
    if rec.AcceptWaveform(data):
        tmpS=rec.Result()
        tmpJ=json.loads(tmpS)
        sonuc_str+=tmpJ["text"]+"\n"
        
        
   # else:      
        #print(rec.PartialResult())


#print(rec.FinalResult())

# %%
print(sonuc_str)
# Out:
# laura went to the stable for horses stood there she put a satellite star he was seven years old begun dark brown her sister came out to the stable they were both gonna exercise the horses it was a warm sunny day
# janice saddled up moonbeam a white mirror they got on the horses and started walking down a few minutes later laura was telling janice about the new doctor and her hospital
# she raised her hand for a second to make a point just then star but laura went flying into the air she landed on her head and shoulder on the grass oh my gosh jan cried laura are you alright laura moaned jan gently rolled her over she didn't see any blood
# that's good she thought can you move your not paralyzed and where are you john paul laura up into a sitting position laura's slightly moved her legs and arms she wasn't paralyzed when she moved her right hand to touch her head she groaned what's the matter
